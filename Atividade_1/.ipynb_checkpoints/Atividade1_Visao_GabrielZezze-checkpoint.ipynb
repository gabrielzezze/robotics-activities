# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.1

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("images/RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
print("Max: {}".format(rintin_gray.max()))
print("Min: {}".format(rintin_gray.min()))
# Out:
# Max: 58
# Min: 8

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# # 1)
# #### O histograma fornecido não aproveita bem as faixas de cores pois no histograma acima pode ser observado que os pixel se encontra entre uma faixa de 8 a 58 enquanto é possivel utilizar uma faixa de 0 a 255.

# %%
img2 = rintin_gray.copy()
# Funcao Reta #
def F(x):
    return (255*x)/50 - 40.8
# Substituicao de pixeis na copia da imagem #
for i in range(len(rintin_gray)):
    for x in range(len(rintin_gray[i])):
        pixel = F(rintin_gray[i][x])
        img2[i][x] = pixel

# %%
# CDF #
hist,bins = np.histogram(img2.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
# Hist Plot #
plt.plot(cdf_normalized, color = 'b')
plt.hist(img2.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.title("Histograma com pixeis ajustados")
plt.show()

# %%
plt.imshow(img2,cmap="Greys_r", vmin=0, vmax=255)
plt.title("Imagem com pixeis ajustados")
plt.show()

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](images/hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %% [markdown]
# # 1)

# %%
img = cv2.imread('images/hall_box_battery1.jpg')

# %% [markdown]
# ### Canal Vermelho

# %%
CanalR = img[:,:,2]
plt.imshow(CanalR, cmap='Greys_r')

# %%
plt.hist(CanalR.flatten(),bins=75,color='r')
plt.title("Canal Vermelho")
plt.show()

# %% [markdown]
# ##### Após a análise da imagem com o canal vermelho separado não é possivel indentificar a caixa vermelha pois o rodapé de cor branca também possui um valor de vermelho elevado no entanto no histograma é possivel sugerir que a caixa vermelha se encontra no pico a direita no qual há uma grande quantidade de pixeis com valor de vermelho elevado(maior que 150) no entanto é provavel que o rodapé tambem esteja incluido nesse pico.

# %% [markdown]
# ### Canal Azul

# %%
CanalB = img[:,:,0]
plt.imshow(CanalB, cmap='Greys_r')

# %%
plt.hist(CanalB.flatten(),bins=50,color='b')
plt.title("Canal Azul")
plt.show()

# %% [markdown]
# #### Após a análise da imagem com o canal azul separado não é possivel indentificar a caixa azul pois como no item acima o rodapé també possui um valor elevado de azul no entanto similar ao item acima ao análisar o histograma é provavel que a caixa azul se encontra no pico a direita do histograma no qual mostra uma grande quantidade de pixeis com valor de azul elevado.

# %% [markdown]
# # 2)

# %%
img2 = cv2.imread('images/hall_box_battery1.jpg')
for i in range(0,len(img2)):
    for x in range(0,len(img2[i])):
        pixel = img2[i][x] 
        if pixel[2] > 150 and pixel[0] < 100:
            img2[i][x] = [255,255,255]
print("Ok!")
# Out:
# Ok!

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Atividade 3
#
#
# Crie uma cópia da versão Grayscale figura acima, em que cada pixel  recebe a subtração entre o pixel que vem depois e o que vem antes dele. Apresente a imagem resultado.

# %% [markdown]
# # 3)

# %%
image3 = cv2.imread('images/hall_box_battery_atividade3.png')
imgGray = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)
img2 = imgGray.copy()

height,width = imgGray.shape
for i in range(0,height):
    for x in range(1,width-1):
        img2[i][x] = abs(int(imgGray[i][x+1]) - int(imgGray[i][x-1]))

# %%
plt.imshow(img2, cmap="Greys_r", vmin=0, vmax=255)
